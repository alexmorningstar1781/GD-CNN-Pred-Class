# %%
import os
from pydub import AudioSegment
from pydub.exceptions import CouldntDecodeError

# Function to split an audio file into 15 segments and distribute them between training and evaluation folders
def split_audio(file_path, train_folder, eval_folder):
    # Get base name and extension of file
    file_name, file_extension = os.path.splitext(os.path.basename(file_path))

    try:
        # Load audio file with format explicitly specified
        audio = AudioSegment.from_file(file_path, format=file_extension[1:])
        
        # Calculate segment duration
        segment_duration = len(audio) // 15  # Divide into 15 segments
        
        # Create output folders if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(eval_folder, exist_ok=True)
        
        # Split and export segments: first 10 for training, last 5 for evaluation
        for i in range(15):
            start_time = i * segment_duration
            end_time = start_time + segment_duration
            
            # Export segment with the same file extension
            segment = audio[start_time:end_time]
            
            if i < 10:
                # Save first 10 segments to the training folder
                output_file = os.path.join(train_folder, f"{file_name}_segment_{i+1}{file_extension}")
            else:
                # Save last 5 segments to the evaluation folder
                output_file = os.path.join(eval_folder, f"{file_name}_segment_{i+1}{file_extension}")
                
            segment.export(output_file, format=file_extension[1:])  # Remove the dot from the extension
            print(f"Exported {output_file}")
    except CouldntDecodeError:
        print(f"Could not decode {file_path}, skipping file.")

# Base directory containing subfolders with audio files
base_dir = 'C://Users/morni/Side Projects/wav_files'

# Define the output directories inside the base directory
train_folder = os.path.join(base_dir, 'output_segments', 'train')
eval_folder = os.path.join(base_dir, 'output_segments', 'eval')

# Walk through all subdirectories in the base directory, skipping 'output_segments'
for root, dirs, files in os.walk(base_dir):
    # Skip processing the 'output_segments' folder
    dirs[:] = [d for d in dirs if d != 'output_segments']
    
    for file in files:
        if file.endswith('.mp3') or file.endswith('.wav'):  # Adjust for more formats if needed
            # Get the full path of the audio file
            file_path = os.path.join(root, file)
            
            # Create an output folder for each subfolder for both training and evaluation
            relative_path = os.path.relpath(root, base_dir)
            subfolder_train = os.path.join(train_folder, relative_path)
            subfolder_eval = os.path.join(eval_folder, relative_path)
            
            # Split the audio file and save the segments
            split_audio(file_path, subfolder_train, subfolder_eval)

# %%
import os
import librosa
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models

# Initialize lists to store features and labels
features = []
labels = []

base_dir = base_dir = 'C://Users/morni/Side Projects/wav_files/output_segments/train'

# Function to extract mel spectrogram and MFCC from audio file
def extract_features(file, max_len=128, n_mfcc=13, hop_length=1024):
    y, sr = librosa.load(file, sr=22050)
    
    # Extract Mel spectrogram
    mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=hop_length)
    mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
    
    # Extract MFCC using the same hop length
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
    
    # Ensure all features have the same length
    if mel_spect_db.shape[1] > max_len:
        mel_spect_db = mel_spect_db[:, :max_len]
    else:
        pad_width = max_len - mel_spect_db.shape[1]
        mel_spect_db = np.pad(mel_spect_db, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    if mfccs.shape[1] > max_len:
        mfccs = mfccs[:, :max_len]
    else:
        pad_width = max_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    
    # Concatenate Mel spectrogram and MFCCs along the first axis
    combined_features = np.concatenate((mel_spect_db, mfccs), axis=0)
    
    return combined_features

# Loop through each folder in the base directory
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    if os.path.isdir(folder_path):
        # Loop through each file in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.wav'):
                file_path = os.path.join(folder_path, file_name)
                
                # Extract combined features (Mel spectrogram + MFCCs)
                combined_features = extract_features(file_path)
                features.append(combined_features)
                
                # Add the label (first letter of folder name as label)
                labels.append(folder_name[0].upper())

# Convert to numpy arrays
X = np.array(features)
y = np.array(labels)

# Encode the labels
unique_labels = np.unique(y)
label_map = {label: i for i, label in enumerate(unique_labels)}
y_encoded = np.array([label_map[label] for label in y])
y_encoded = to_categorical(y_encoded, num_classes=len(unique_labels))

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=442)

# Add a channel dimension for CNN
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Add an Input layer
model = models.Sequential()
model.add(layers.Input(shape=(141, 128, 1)))  # Specify input shape (141 = 128 Mel bands + 13 MFCCs)

# First Conv Layer
model.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Second Conv Layer
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# third Conv Layer
model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Flatten and add Dense layers
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.3))  # Prevent overfitting
model.add(layers.Dense(len(unique_labels), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc}")

# Predict the labels for the test set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plotting accuracy over epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 422ms/step - accuracy: 0.1893 - loss: 8.4805 - val_accuracy: 0.2676 - val_loss: 1.5935
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.2537 - loss: 1.5768 - val_accuracy: 0.2958 - val_loss: 1.5807
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 406ms/step - accuracy: 0.3016 - loss: 1.5376 - val_accuracy: 0.2746 - val_loss: 1.5980
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 405ms/step - accuracy: 0.2878 - loss: 1.5319 - val_accuracy: 0.2465 - val_loss: 1.6495
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 411ms/step - accuracy: 0.2716 - loss: 1.5116 - val_accuracy: 0.2676 - val_loss: 1.5842
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 422ms/step - accuracy: 0.2988 - loss: 1.5064 - val_accuracy: 0.2887 - val_loss: 1.6363
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 422ms/step - accuracy: 0.3156 - loss: 1.4702 - val_accuracy: 0.2817 - val_loss: 1.5940
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.3283 - loss: 1.4990 - val_accuracy: 0.2535 - val_loss: 1.6742
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 422ms/step - accuracy: 0.4180 - loss: 1.4076 - val_accuracy: 0.3944 - val_loss: 1.5372
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 465ms/step - accuracy: 0.4976 - loss: 1.2711 - val_accuracy: 0.4296 - val_loss: 1.2995
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - accuracy: 0.5577 - loss: 1.1377 - val_accuracy: 0.5141 - val_loss: 1.2782
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 432ms/step - accuracy: 0.6287 - loss: 0.9402 - val_accuracy: 0.5563 - val_loss: 1.0982
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 408ms/step - accuracy: 0.6667 - loss: 0.8669 - val_accuracy: 0.5845 - val_loss: 1.0216
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 419ms/step - accuracy: 0.7369 - loss: 0.7487 - val_accuracy: 0.6197 - val_loss: 1.2409
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 420ms/step - accuracy: 0.7710 - loss: 0.6892 - val_accuracy: 0.6056 - val_loss: 1.2563
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - accuracy: 0.7375 - loss: 0.7032 - val_accuracy: 0.6197 - val_loss: 1.0128
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 419ms/step - accuracy: 0.7865 - loss: 0.6067 - val_accuracy: 0.6479 - val_loss: 1.1085
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 432ms/step - accuracy: 0.8282 - loss: 0.4848 - val_accuracy: 0.7183 - val_loss: 0.8793
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 418ms/step - accuracy: 0.8839 - loss: 0.3497 - val_accuracy: 0.6479 - val_loss: 0.9809
# Epoch 20/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 439ms/step - accuracy: 0.8223 - loss: 0.5062 - val_accuracy: 0.6479 - val_loss: 0.9658
# Epoch 21/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 442ms/step - accuracy: 0.7570 - loss: 0.6104 - val_accuracy: 0.7746 - val_loss: 0.7330
# Epoch 22/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.8874 - loss: 0.3381 - val_accuracy: 0.7042 - val_loss: 1.0784
# Epoch 23/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 420ms/step - accuracy: 0.8774 - loss: 0.3653 - val_accuracy: 0.7042 - val_loss: 1.2946
# Epoch 24/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.9348 - loss: 0.2120 - val_accuracy: 0.7254 - val_loss: 1.2675
# Epoch 25/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 423ms/step - accuracy: 0.9129 - loss: 0.2435 - val_accuracy: 0.7394 - val_loss: 1.0902
# Epoch 26/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.9335 - loss: 0.2214 - val_accuracy: 0.6831 - val_loss: 1.7451
# Epoch 27/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 423ms/step - accuracy: 0.9261 - loss: 0.2571 - val_accuracy: 0.7606 - val_loss: 1.1774
# Epoch 28/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 440ms/step - accuracy: 0.9353 - loss: 0.1752 - val_accuracy: 0.7606 - val_loss: 1.2030
# Epoch 29/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 424ms/step - accuracy: 0.9356 - loss: 0.1915 - val_accuracy: 0.7042 - val_loss: 1.0834
# Epoch 30/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.9324 - loss: 0.2065 - val_accuracy: 0.6972 - val_loss: 1.3125
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7011 - loss: 1.1891
# Test Accuracy: 0.6971830725669861
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step

# %%
model.save('C://Users/morni/Side Projects/wav_files/GD_class_mdl.keras')

# %%
import os
import librosa
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models

# Initialize lists to store features and labels
features = []
labels = []

# Define base directory where your .wav files are located
base_dir = 'C://Users/morni/Side Projects/wav_files/output_segments/eval'

# Function to extract mel spectrogram and MFCC from audio file
def extract_features(file, max_len=128, n_mfcc=13, hop_length=1024):
    y, sr = librosa.load(file, sr=22050)
    
    # Extract Mel spectrogram
    mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=hop_length)
    mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
    
    # Extract MFCC using the same hop length
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
    
    # Ensure all features have the same length
    if mel_spect_db.shape[1] > max_len:
        mel_spect_db = mel_spect_db[:, :max_len]
    else:
        pad_width = max_len - mel_spect_db.shape[1]
        mel_spect_db = np.pad(mel_spect_db, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    if mfccs.shape[1] > max_len:
        mfccs = mfccs[:, :max_len]
    else:
        pad_width = max_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    
    # Concatenate Mel spectrogram and MFCCs along the first axis
    features = np.concatenate((mel_spect_db, mfccs), axis=0)
    
    return features

# Loop through each folder in the base directory
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    if os.path.isdir(folder_path):
        # Assign the folder name (or some characteristic) as the label
        label = folder_name[0].upper()  # E.g., first letter of folder name as label
        
        # Loop through each file in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.wav'):
                file_path = os.path.join(folder_path, file_name)
                
                # Extract combined features (Mel spectrogram + MFCCs)
                combined_features = extract_features(file_path)
                features.append(combined_features)
                
                # Append the corresponding label for each file
                labels.append(label)

# Convert to numpy arrays
X = np.array(features)
y = np.array(labels)

# Encode the labels
unique_labels = np.unique(y)
label_map = {label: i for i, label in enumerate(unique_labels)}
y_encoded = np.array([label_map[label] for label in y])
y_encoded = to_categorical(y_encoded, num_classes=len(unique_labels))

# Add a channel dimension to the features for CNN input (batch, height, width, channel)
X = X[..., np.newaxis]

# Load the saved model
loaded_model = tf.keras.models.load_model('C://Users/morni/Side Projects/wav_files/GD_class_mdl.keras')

# Use the model to predict
predictions = loaded_model.predict(X)

# Get the predicted class labels
predicted_classes = np.argmax(predictions, axis=1)

# Map predicted class indices back to original labels
predicted_labels = [unique_labels[i] for i in predicted_classes]

# Print the actual labels and the predicted labels
for i, predicted_label in enumerate(predicted_labels):
    actual_label = y[i]  # Get the actual label from the original labels array
    print(f"Sample {i}: Actual label: {actual_label}, Predicted label: {predicted_label}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step
# Sample 0: Actual label: D, Predicted label: D
# Sample 1: Actual label: D, Predicted label: D
# Sample 2: Actual label: D, Predicted label: D
# Sample 3: Actual label: D, Predicted label: D
# Sample 4: Actual label: D, Predicted label: D
# Sample 5: Actual label: D, Predicted label: S
# Sample 6: Actual label: D, Predicted label: D
# Sample 7: Actual label: D, Predicted label: D
# Sample 8: Actual label: D, Predicted label: D
# Sample 9: Actual label: D, Predicted label: D
# Sample 10: Actual label: D, Predicted label: D
# Sample 11: Actual label: D, Predicted label: S
# Sample 12: Actual label: D, Predicted label: D
# Sample 13: Actual label: D, Predicted label: S
# Sample 14: Actual label: D, Predicted label: S
# Sample 15: Actual label: D, Predicted label: D
# Sample 16: Actual label: D, Predicted label: D
# Sample 17: Actual label: D, Predicted label: D
# Sample 18: Actual label: D, Predicted label: D
# Sample 19: Actual label: D, Predicted label: D
# Sample 20: Actual label: D, Predicted label: D
# Sample 21: Actual label: D, Predicted label: D
# Sample 22: Actual label: D, Predicted label: D
# Sample 23: Actual label: D, Predicted label: D
# Sample 24: Actual label: D, Predicted label: D
# Sample 25: Actual label: D, Predicted label: D
# Sample 26: Actual label: D, Predicted label: S
# Sample 27: Actual label: D, Predicted label: D
# Sample 28: Actual label: D, Predicted label: D
# Sample 29: Actual label: D, Predicted label: D
# Sample 30: Actual label: D, Predicted label: D
# Sample 31: Actual label: D, Predicted label: D
# Sample 32: Actual label: D, Predicted label: D
# Sample 33: Actual label: D, Predicted label: I
# Sample 34: Actual label: D, Predicted label: D
# Sample 35: Actual label: D, Predicted label: W
# Sample 36: Actual label: D, Predicted label: S
# Sample 37: Actual label: D, Predicted label: S
# Sample 38: Actual label: D, Predicted label: D
# Sample 39: Actual label: D, Predicted label: D
# Sample 40: Actual label: D, Predicted label: D
# Sample 41: Actual label: D, Predicted label: D
# Sample 42: Actual label: D, Predicted label: S
# Sample 43: Actual label: D, Predicted label: D
# Sample 44: Actual label: D, Predicted label: D
# Sample 45: Actual label: D, Predicted label: D
# Sample 46: Actual label: D, Predicted label: D
# Sample 47: Actual label: D, Predicted label: D
# Sample 48: Actual label: D, Predicted label: I
# Sample 49: Actual label: D, Predicted label: I
# Sample 50: Actual label: D, Predicted label: D
# Sample 51: Actual label: D, Predicted label: D
# Sample 52: Actual label: D, Predicted label: D
# Sample 53: Actual label: D, Predicted label: D
# Sample 54: Actual label: D, Predicted label: D
# Sample 55: Actual label: D, Predicted label: D
# Sample 56: Actual label: D, Predicted label: D
# Sample 57: Actual label: D, Predicted label: D
# Sample 58: Actual label: D, Predicted label: D
# Sample 59: Actual label: D, Predicted label: D
# Sample 60: Actual label: D, Predicted label: S
# Sample 61: Actual label: D, Predicted label: D
# Sample 62: Actual label: D, Predicted label: S
# Sample 63: Actual label: D, Predicted label: D
# Sample 64: Actual label: D, Predicted label: D
# Sample 65: Actual label: I, Predicted label: I
# Sample 66: Actual label: I, Predicted label: I
# Sample 67: Actual label: I, Predicted label: I
# Sample 68: Actual label: I, Predicted label: I
# Sample 69: Actual label: I, Predicted label: I
# Sample 70: Actual label: I, Predicted label: I
# Sample 71: Actual label: I, Predicted label: I
# Sample 72: Actual label: I, Predicted label: I
# Sample 73: Actual label: I, Predicted label: D
# Sample 74: Actual label: I, Predicted label: I
# Sample 75: Actual label: I, Predicted label: I
# Sample 76: Actual label: I, Predicted label: I
# Sample 77: Actual label: I, Predicted label: I
# Sample 78: Actual label: I, Predicted label: I
# Sample 79: Actual label: I, Predicted label: I
# Sample 80: Actual label: I, Predicted label: W
# Sample 81: Actual label: I, Predicted label: D
# Sample 82: Actual label: I, Predicted label: I
# Sample 83: Actual label: I, Predicted label: I
# Sample 84: Actual label: I, Predicted label: I
# Sample 85: Actual label: I, Predicted label: I
# Sample 86: Actual label: I, Predicted label: I
# Sample 87: Actual label: I, Predicted label: I
# Sample 88: Actual label: I, Predicted label: I
# Sample 89: Actual label: I, Predicted label: I
# Sample 90: Actual label: I, Predicted label: I
# Sample 91: Actual label: I, Predicted label: I
# Sample 92: Actual label: I, Predicted label: I
# Sample 93: Actual label: I, Predicted label: I
# Sample 94: Actual label: I, Predicted label: I
# Sample 95: Actual label: I, Predicted label: I
# Sample 96: Actual label: I, Predicted label: I
# Sample 97: Actual label: I, Predicted label: I
# Sample 98: Actual label: I, Predicted label: I
# Sample 99: Actual label: I, Predicted label: I
# Sample 100: Actual label: I, Predicted label: I
# Sample 101: Actual label: I, Predicted label: S
# Sample 102: Actual label: I, Predicted label: I
# Sample 103: Actual label: I, Predicted label: I
# Sample 104: Actual label: I, Predicted label: I
# Sample 105: Actual label: I, Predicted label: I
# Sample 106: Actual label: I, Predicted label: I
# Sample 107: Actual label: I, Predicted label: I
# Sample 108: Actual label: I, Predicted label: I
# Sample 109: Actual label: I, Predicted label: I
# Sample 110: Actual label: I, Predicted label: I
# Sample 111: Actual label: I, Predicted label: I
# Sample 112: Actual label: I, Predicted label: I
# Sample 113: Actual label: I, Predicted label: I
# Sample 114: Actual label: I, Predicted label: I
# Sample 115: Actual label: I, Predicted label: I
# Sample 116: Actual label: I, Predicted label: I
# Sample 117: Actual label: I, Predicted label: I
# Sample 118: Actual label: I, Predicted label: I
# Sample 119: Actual label: I, Predicted label: I
# Sample 120: Actual label: I, Predicted label: I
# Sample 121: Actual label: I, Predicted label: I
# Sample 122: Actual label: I, Predicted label: I
# Sample 123: Actual label: I, Predicted label: I
# Sample 124: Actual label: I, Predicted label: I
# Sample 125: Actual label: I, Predicted label: I
# Sample 126: Actual label: I, Predicted label: I
# Sample 127: Actual label: I, Predicted label: S
# Sample 128: Actual label: I, Predicted label: I
# Sample 129: Actual label: I, Predicted label: I
# Sample 130: Actual label: I, Predicted label: I
# Sample 131: Actual label: I, Predicted label: I
# Sample 132: Actual label: I, Predicted label: I
# Sample 133: Actual label: I, Predicted label: I
# Sample 134: Actual label: I, Predicted label: I
# Sample 135: Actual label: N, Predicted label: N
# Sample 136: Actual label: N, Predicted label: N
# Sample 137: Actual label: N, Predicted label: S
# Sample 138: Actual label: N, Predicted label: N
# Sample 139: Actual label: N, Predicted label: N
# Sample 140: Actual label: N, Predicted label: N
# Sample 141: Actual label: N, Predicted label: N
# Sample 142: Actual label: N, Predicted label: N
# Sample 143: Actual label: N, Predicted label: N
# Sample 144: Actual label: N, Predicted label: N
# Sample 145: Actual label: N, Predicted label: N
# Sample 146: Actual label: N, Predicted label: N
# Sample 147: Actual label: N, Predicted label: N
# Sample 148: Actual label: N, Predicted label: N
# Sample 149: Actual label: N, Predicted label: W
# Sample 150: Actual label: N, Predicted label: N
# Sample 151: Actual label: N, Predicted label: N
# Sample 152: Actual label: N, Predicted label: S
# Sample 153: Actual label: N, Predicted label: N
# Sample 154: Actual label: N, Predicted label: N
# Sample 155: Actual label: N, Predicted label: N
# Sample 156: Actual label: N, Predicted label: N
# Sample 157: Actual label: N, Predicted label: N
# Sample 158: Actual label: N, Predicted label: N
# Sample 159: Actual label: N, Predicted label: N
# Sample 160: Actual label: N, Predicted label: N
# Sample 161: Actual label: N, Predicted label: N
# Sample 162: Actual label: N, Predicted label: N
# Sample 163: Actual label: N, Predicted label: N
# Sample 164: Actual label: N, Predicted label: D
# Sample 165: Actual label: N, Predicted label: N
# Sample 166: Actual label: N, Predicted label: N
# Sample 167: Actual label: N, Predicted label: S
# Sample 168: Actual label: N, Predicted label: N
# Sample 169: Actual label: N, Predicted label: N
# Sample 170: Actual label: N, Predicted label: S
# Sample 171: Actual label: N, Predicted label: S
# Sample 172: Actual label: N, Predicted label: S
# Sample 173: Actual label: N, Predicted label: S
# Sample 174: Actual label: N, Predicted label: S
# Sample 175: Actual label: N, Predicted label: S
# Sample 176: Actual label: N, Predicted label: N
# Sample 177: Actual label: N, Predicted label: S
# Sample 178: Actual label: N, Predicted label: N
# Sample 179: Actual label: N, Predicted label: N
# Sample 180: Actual label: N, Predicted label: N
# Sample 181: Actual label: N, Predicted label: N
# Sample 182: Actual label: N, Predicted label: N
# Sample 183: Actual label: N, Predicted label: N
# Sample 184: Actual label: N, Predicted label: N
# Sample 185: Actual label: N, Predicted label: I
# Sample 186: Actual label: N, Predicted label: N
# Sample 187: Actual label: N, Predicted label: N
# Sample 188: Actual label: N, Predicted label: N
# Sample 189: Actual label: N, Predicted label: N
# Sample 190: Actual label: N, Predicted label: N
# Sample 191: Actual label: N, Predicted label: N
# Sample 192: Actual label: N, Predicted label: N
# Sample 193: Actual label: N, Predicted label: N
# Sample 194: Actual label: N, Predicted label: D
# Sample 195: Actual label: N, Predicted label: N
# Sample 196: Actual label: N, Predicted label: N
# Sample 197: Actual label: N, Predicted label: N
# Sample 198: Actual label: N, Predicted label: N
# Sample 199: Actual label: N, Predicted label: N
# Sample 200: Actual label: N, Predicted label: N
# Sample 201: Actual label: N, Predicted label: S
# Sample 202: Actual label: N, Predicted label: N
# Sample 203: Actual label: N, Predicted label: N
# Sample 204: Actual label: N, Predicted label: S
# Sample 205: Actual label: N, Predicted label: N
# Sample 206: Actual label: N, Predicted label: N
# Sample 207: Actual label: N, Predicted label: N
# Sample 208: Actual label: N, Predicted label: I
# Sample 209: Actual label: N, Predicted label: D
# Sample 210: Actual label: N, Predicted label: N
# Sample 211: Actual label: N, Predicted label: N
# Sample 212: Actual label: N, Predicted label: N
# Sample 213: Actual label: N, Predicted label: N
# Sample 214: Actual label: N, Predicted label: N
# Sample 215: Actual label: N, Predicted label: N
# Sample 216: Actual label: N, Predicted label: N
# Sample 217: Actual label: N, Predicted label: N
# Sample 218: Actual label: N, Predicted label: N
# Sample 219: Actual label: N, Predicted label: D
# Sample 220: Actual label: N, Predicted label: I
# Sample 221: Actual label: N, Predicted label: N
# Sample 222: Actual label: N, Predicted label: N
# Sample 223: Actual label: N, Predicted label: N
# Sample 224: Actual label: N, Predicted label: N
# Sample 225: Actual label: S, Predicted label: S
# Sample 226: Actual label: S, Predicted label: I
# Sample 227: Actual label: S, Predicted label: S
# Sample 228: Actual label: S, Predicted label: S
# Sample 229: Actual label: S, Predicted label: I
# Sample 230: Actual label: S, Predicted label: I
# Sample 231: Actual label: S, Predicted label: I
# Sample 232: Actual label: S, Predicted label: I
# Sample 233: Actual label: S, Predicted label: I
# Sample 234: Actual label: S, Predicted label: I
# Sample 235: Actual label: S, Predicted label: S
# Sample 236: Actual label: S, Predicted label: I
# Sample 237: Actual label: S, Predicted label: I
# Sample 238: Actual label: S, Predicted label: S
# Sample 239: Actual label: S, Predicted label: I
# Sample 240: Actual label: S, Predicted label: N
# Sample 241: Actual label: S, Predicted label: S
# Sample 242: Actual label: S, Predicted label: S
# Sample 243: Actual label: S, Predicted label: N
# Sample 244: Actual label: S, Predicted label: S
# Sample 245: Actual label: S, Predicted label: S
# Sample 246: Actual label: S, Predicted label: S
# Sample 247: Actual label: S, Predicted label: N
# Sample 248: Actual label: S, Predicted label: S
# Sample 249: Actual label: S, Predicted label: D
# Sample 250: Actual label: S, Predicted label: S
# Sample 251: Actual label: S, Predicted label: S
# Sample 252: Actual label: S, Predicted label: S
# Sample 253: Actual label: S, Predicted label: S
# Sample 254: Actual label: S, Predicted label: S
# Sample 255: Actual label: S, Predicted label: S
# Sample 256: Actual label: S, Predicted label: S
# Sample 257: Actual label: S, Predicted label: I
# Sample 258: Actual label: S, Predicted label: I
# Sample 259: Actual label: S, Predicted label: S
# Sample 260: Actual label: S, Predicted label: S
# Sample 261: Actual label: S, Predicted label: S
# Sample 262: Actual label: S, Predicted label: S
# Sample 263: Actual label: S, Predicted label: S
# Sample 264: Actual label: S, Predicted label: S
# Sample 265: Actual label: S, Predicted label: I
# Sample 266: Actual label: S, Predicted label: S
# Sample 267: Actual label: S, Predicted label: S
# Sample 268: Actual label: S, Predicted label: I
# Sample 269: Actual label: S, Predicted label: S
# Sample 270: Actual label: S, Predicted label: S
# Sample 271: Actual label: S, Predicted label: S
# Sample 272: Actual label: S, Predicted label: D
# Sample 273: Actual label: S, Predicted label: S
# Sample 274: Actual label: S, Predicted label: S
# Sample 275: Actual label: S, Predicted label: I
# Sample 276: Actual label: S, Predicted label: I
# Sample 277: Actual label: S, Predicted label: S
# Sample 278: Actual label: S, Predicted label: S
# Sample 279: Actual label: S, Predicted label: I
# Sample 280: Actual label: S, Predicted label: N
# Sample 281: Actual label: S, Predicted label: N
# Sample 282: Actual label: S, Predicted label: S
# Sample 283: Actual label: S, Predicted label: N
# Sample 284: Actual label: S, Predicted label: S
# Sample 285: Actual label: S, Predicted label: S
# Sample 286: Actual label: S, Predicted label: D
# Sample 287: Actual label: S, Predicted label: S
# Sample 288: Actual label: S, Predicted label: D
# Sample 289: Actual label: S, Predicted label: I
# Sample 290: Actual label: S, Predicted label: S
# Sample 291: Actual label: S, Predicted label: S
# Sample 292: Actual label: S, Predicted label: I
# Sample 293: Actual label: S, Predicted label: S
# Sample 294: Actual label: S, Predicted label: S
# Sample 295: Actual label: W, Predicted label: N
# Sample 296: Actual label: W, Predicted label: W
# Sample 297: Actual label: W, Predicted label: D
# Sample 298: Actual label: W, Predicted label: W
# Sample 299: Actual label: W, Predicted label: D
# Sample 300: Actual label: W, Predicted label: W
# Sample 301: Actual label: W, Predicted label: W
# Sample 302: Actual label: W, Predicted label: W
# Sample 303: Actual label: W, Predicted label: S
# Sample 304: Actual label: W, Predicted label: S
# Sample 305: Actual label: W, Predicted label: W
# Sample 306: Actual label: W, Predicted label: I
# Sample 307: Actual label: W, Predicted label: W
# Sample 308: Actual label: W, Predicted label: W
# Sample 309: Actual label: W, Predicted label: W
# Sample 310: Actual label: W, Predicted label: W
# Sample 311: Actual label: W, Predicted label: W
# Sample 312: Actual label: W, Predicted label: W
# Sample 313: Actual label: W, Predicted label: W
# Sample 314: Actual label: W, Predicted label: N
# Sample 315: Actual label: W, Predicted label: S
# Sample 316: Actual label: W, Predicted label: I
# Sample 317: Actual label: W, Predicted label: W
# Sample 318: Actual label: W, Predicted label: I
# Sample 319: Actual label: W, Predicted label: W
# Sample 320: Actual label: W, Predicted label: N
# Sample 321: Actual label: W, Predicted label: N
# Sample 322: Actual label: W, Predicted label: W
# Sample 323: Actual label: W, Predicted label: W
# Sample 324: Actual label: W, Predicted label: W
# Sample 325: Actual label: W, Predicted label: W
# Sample 326: Actual label: W, Predicted label: W
# Sample 327: Actual label: W, Predicted label: W
# Sample 328: Actual label: W, Predicted label: W
# Sample 329: Actual label: W, Predicted label: D
# Sample 330: Actual label: W, Predicted label: W
# Sample 331: Actual label: W, Predicted label: W
# Sample 332: Actual label: W, Predicted label: W
# Sample 333: Actual label: W, Predicted label: W
# Sample 334: Actual label: W, Predicted label: W
# Sample 335: Actual label: W, Predicted label: W
# Sample 336: Actual label: W, Predicted label: N
# Sample 337: Actual label: W, Predicted label: W
# Sample 338: Actual label: W, Predicted label: W
# Sample 339: Actual label: W, Predicted label: I
# Sample 340: Actual label: W, Predicted label: S
# Sample 341: Actual label: W, Predicted label: W
# Sample 342: Actual label: W, Predicted label: S
# Sample 343: Actual label: W, Predicted label: W
# Sample 344: Actual label: W, Predicted label: W
# Sample 345: Actual label: W, Predicted label: W
# Sample 346: Actual label: W, Predicted label: S
# Sample 347: Actual label: W, Predicted label: I
# Sample 348: Actual label: W, Predicted label: W
# Sample 349: Actual label: W, Predicted label: W
# Sample 350: Actual label: W, Predicted label: W
# Sample 351: Actual label: W, Predicted label: W
# Sample 352: Actual label: W, Predicted label: W
# Sample 353: Actual label: W, Predicted label: W
# Sample 354: Actual label: W, Predicted label: W

# %% [markdown]
# For label "D": 54 correct predictions out of 82
# For label "I": 58 correct predictions out of 61
# For label "N": 71 correct predictions out of 90
# For label "S": 31 correct predictions out of 55
# For label "W": 43 correct predictions out of 50
#
# The accuracy of the predicted vs. actual labels is approximately 72.39%.
